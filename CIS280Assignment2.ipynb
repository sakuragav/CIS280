# %% [markdown]
# <a href="https://colab.research.google.com/github/sakuragav/CIS280/blob/Assignments/CIS280Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Consider the dataset available at the Link that contains customer information for all the
# transactions made on the Black Friday for a retail store
#
#   i (2 pts) Display the first 5 rows of the dataset. Do we observe any missing values? If
# yes, drop all the missing values from your dataset. Make sure to include your code
# and output.
#
#   ii (3 pts) Use .countplot() function to create a count plot showing the ages for each
# gender group. Make sure to include your code and output.
#
#   iii (2 pts) Based on the plot in part (ii), which gender seems to be prevelant across all
# age groups? Explain.
#
#   iv (3 pts) Create a box plot displaying Gender versus Purchase, grouped by their marital
# status. From the plot, determine which sex and marital status has the most purchasing
# power? Make sure to include your code and output.

# %%
import seaborn as sns
import pandas as pd
bf = pd.read_csv("https://raw.githubusercontent.com/stellahrotich/MLProjects101/master/BlackFriday.csv")
bf1 = bf.dropna()

# %%
g = sns.countplot('Age', data = bf, hue = 'Gender')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = 'Gender', y = 'Purchase', data = bf1, hue = 'Marital_Status')

# %%
sns.barplot('Gender', 'Purchase', data = bf1, hue = 'Marital_Status')
